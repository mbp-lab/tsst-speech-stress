# %% [markdown]
# # Satistical testing regression models

# %%
import pandas as pd
import numpy as np
import os
import sys
import mystats

# %%
homepath=os.getcwd()
scripts_path=os.path.join(homepath, 'scripts')
sys.path.append(scripts_path)

# %%
# Check version of Python==64
# !python -c "import sys; print(sys.maxsize > 2**32)"

# random seed for reproducability
np.random.seed(42)

# show all columns of dataframes
pd.set_option('display.max_columns', None)

# set current dir to highest hierachy to add data path
os.chdir('/')
data_folder='/data'

sys.path.append(data_folder)
os.chdir(homepath)
# Out:
# True

# %% [markdown]
# # Statistical testing (Corrected paired t-test)

# %% [markdown]
# Here we are using the corrected paired t-test proposed by Nadeau and Bengio to compare the model performance against the baseline (mean absolute value)

# %% [markdown]
# ## For models used only TSST data

# %% [markdown]
# ### Random Forest Regressor

# %%
RF_score_csvs = [
    "RF_cortisol_react_loo_abs_error.csv",
    "RF_cort_20_min_loo_abs_error.csv",
    "RF_saa_react_loo_abs_error.csv",
    "RF_pana_delta_na_loo_abs_error.csv",
    "RF_pana_delta_pa_loo_abs_error.csv"
]

for csv in RF_score_csvs:
    df = pd.read_csv(csv)

    differences = df["baseline_abs_error"].values - df["model_abs_error"].values

    n = differences.shape[0]
    dfree = n - 1
    n_train = 24
    n_test = 1    

    t_stat, p_val = mystats.compute_corrected_ttest(
        differences, dfree, n_train, n_test
    )

    mean_abs_error_model = np.mean(df["model_abs_error"].values)
    mean_abs_error_baseline = np.mean(df["baseline_abs_error"].values)

    print(csv)
    print("----------------------")
    print(f"Corrected t-value: {t_stat:.3f}")
    print(f"Corrected p-value: {p_val:.3f}")
    print(f"Mean difference (abs): {np.mean(differences)}")
    print(f"Mean abs error model: {mean_abs_error_model}")
    print(f"Mean abs error baseline: {mean_abs_error_baseline}")
    print()
# Out:
# RF_cortisol_react_loo_abs_error.csv
# ----------------------
# Corrected t-value: 0.726
# Corrected p-value: 0.237
# Mean difference (abs): 0.6220271043340391
# Mean abs error model: 4.927355083532628
# Mean abs error baseline: 5.549382187866667
#
# RF_cort_20_min_loo_abs_error.csv
# ----------------------
# Corrected t-value: -0.346
# Corrected p-value: 0.366
# Mean difference (abs): -0.2803184240872328
# Mean abs error model: 5.805946007420566
# Mean abs error baseline: 5.525627583333334
#
# RF_saa_react_loo_abs_error.csv
# ----------------------
# Corrected t-value: 0.368
# Corrected p-value: 0.358
# Mean difference (abs): 2.207386203498388
# Mean abs error model: 40.136190463168276
# Mean abs error baseline: 42.34357666666667
#
# RF_pana_delta_na_loo_abs_error.csv
# ----------------------
# Corrected t-value: 0.935
# Corrected p-value: 0.180
# Mean difference (abs): 0.40528848935636075
# Mean abs error model: 2.814711510643639
# Mean abs error baseline: 3.2200000000000006
#
# RF_pana_delta_pa_loo_abs_error.csv
# ----------------------
# Corrected t-value: -0.162
# Corrected p-value: 0.436
# Mean difference (abs): -0.07008639140237147
# Mean abs error model: 3.786753058069038
# Mean abs error baseline: 3.7166666666666663

# %% [markdown]
# ### Support Vector Regressor

# %%
RF_score_csvs = ["SVR_cortisol_react_loo_abs_error.csv", "SVR_cort_20_min_loo_abs_error.csv",
                 "SVR_saa_react_loo_abs_error.csv", "SVR_pana_delta_na_loo_abs_error.csv",
                 "SVR_pana_delta_pa_loo_abs_error.csv"]

for csv in RF_score_csvs:
    df = pd.read_csv(csv)

    differences = df["baseline_abs_error"].values - df["model_abs_error"].values

    n = differences.shape[0]
    dfree = n - 1
    n_train = 24
    n_test  = 1    

    t_stat, p_val = mystats.compute_corrected_ttest(
        differences, dfree, n_train, n_test
    )
    mean_abs_error_model = np.mean(df["model_abs_error"].values)
    mean_abs_error_baseline = np.mean(df["baseline_abs_error"].values)

    print(csv)
    print("----------------------")
    print(f"Corrected t-value: {t_stat:.3f}")
    print(f"Corrected p-value: {p_val:.3f}")
    print(f"Mean difference (abs): {np.mean(differences)}")
    print(f"Mean abs error model: {mean_abs_error_model}")
    print(f"Mean abs error baseline: {mean_abs_error_baseline}")
    print()
# Out:
# SVR_cortisol_react_loo_abs_error.csv
# ----------------------
# Corrected t-value: 1.483
# Corrected p-value: 0.076
# Mean difference (abs): 1.1157484873493053
# Mean abs error model: 4.433633700517362
# Mean abs error baseline: 5.549382187866667
#
# SVR_cort_20_min_loo_abs_error.csv
# ----------------------
# Corrected t-value: -1.302
# Corrected p-value: 0.103
# Mean difference (abs): -0.6747469421820385
# Mean abs error model: 6.200374525515372
# Mean abs error baseline: 5.525627583333334
#
# SVR_saa_react_loo_abs_error.csv
# ----------------------
# Corrected t-value: -0.212
# Corrected p-value: 0.417
# Mean difference (abs): -1.0908710181758148
# Mean abs error model: 43.43444768484247
# Mean abs error baseline: 42.34357666666667
#
# SVR_pana_delta_na_loo_abs_error.csv
# ----------------------
# Corrected t-value: -0.506
# Corrected p-value: 0.309
# Mean difference (abs): -0.2299273755848531
# Mean abs error model: 3.449927375584853
# Mean abs error baseline: 3.2200000000000006
#
# SVR_pana_delta_pa_loo_abs_error.csv
# ----------------------
# Corrected t-value: -0.688
# Corrected p-value: 0.249
# Mean difference (abs): -0.23836453861263354
# Mean abs error model: 3.9550312052792997
# Mean abs error baseline: 3.7166666666666663

# %% [markdown]
# ### XGBoost

# %%
RF_score_csvs = ["XGB_cortisol_react_loo_abs_error.csv", "XGB_cort_20_min_loo_abs_error.csv",
                 "XGB_saa_react_loo_abs_error.csv", "XGB_pana_delta_na_loo_abs_error.csv",
                 "XGB_pana_delta_pa_loo_abs_error.csv"]

for csv in RF_score_csvs:
    df = pd.read_csv(csv)

    differences = df["baseline_abs_error"].values - df["model_abs_error"].values

    n = differences.shape[0]
    dfree = n - 1
    n_train = 24
    n_test  = 1    

    t_stat, p_val = mystats.compute_corrected_ttest(
        differences, dfree, n_train, n_test
    )
    mean_abs_error_model = np.mean(df["model_abs_error"].values)
    mean_abs_error_baseline = np.mean(df["baseline_abs_error"].values)

    print(csv)
    print("----------------------")
    print(f"Corrected t-value: {t_stat:.3f}")
    print(f"Corrected p-value: {p_val:.3f}")
    print(f"Mean difference (abs): {np.mean(differences)}")
    print(f"Mean abs error model: {mean_abs_error_model}")
    print(f"Mean abs error baseline: {mean_abs_error_baseline}")
    print()
# Out:
# XGB_cortisol_react_loo_abs_error.csv
# ----------------------
# Corrected t-value: -0.004
# Corrected p-value: 0.499
# Mean difference (abs): -0.0038056170950889444
# Mean abs error model: 5.553187804961755
# Mean abs error baseline: 5.549382187866667
#
# XGB_cort_20_min_loo_abs_error.csv
# ----------------------
# Corrected t-value: -0.390
# Corrected p-value: 0.350
# Mean difference (abs): -0.25743485367701774
# Mean abs error model: 5.783062437010351
# Mean abs error baseline: 5.525627583333334
#
# XGB_saa_react_loo_abs_error.csv
# ----------------------
# Corrected t-value: -0.789
# Corrected p-value: 0.219
# Mean difference (abs): -7.705797533772788
# Mean abs error model: 50.04937420043945
# Mean abs error baseline: 42.34357666666667
#
# XGB_pana_delta_na_loo_abs_error.csv
# ----------------------
# Corrected t-value: 2.107
# Corrected p-value: 0.023
# Mean difference (abs): 1.137488352060318
# Mean abs error model: 2.082511647939682
# Mean abs error baseline: 3.2200000000000006
#
# XGB_pana_delta_pa_loo_abs_error.csv
# ----------------------
# Corrected t-value: -0.042
# Corrected p-value: 0.483
# Mean difference (abs): -0.022278059323628873
# Mean abs error model: 3.7389447259902955
# Mean abs error baseline: 3.7166666666666663

# %% [markdown]
# # For Models used TSST and FTSST data

# %% [markdown]
# ### Random Forest Regressor

# %%
RF_score_csvs = [
    "RF_full_cortisol_react_loo_abs_error.csv",
    "RF_full_cort_20_min_loo_abs_error.csv",
    "RF_full_saa_react_loo_abs_error.csv",
    "RF_full_pana_delta_na_loo_abs_error.csv",
    "RF_full_pana_delta_pa_loo_abs_error.csv"
]

for csv in RF_score_csvs:
    df = pd.read_csv(csv)

    differences = df["baseline_abs_error"].values - df["model_abs_error"].values

    n = differences.shape[0]
    dfree = n - 1
    n_train = 24
    n_test = 1    

    t_stat, p_val = mystats.compute_corrected_ttest(
        differences, dfree, n_train, n_test
    )

    mean_abs_error_model = np.mean(df["model_abs_error"].values)
    mean_abs_error_baseline = np.mean(df["baseline_abs_error"].values)

    print(csv)
    print("----------------------")
    print(f"Corrected t-value: {t_stat:.3f}")
    print(f"Corrected p-value: {p_val:.3f}")
    print(f"Mean difference (abs): {np.mean(differences)}")
    print(f"Mean abs error model: {mean_abs_error_model}")
    print(f"Mean abs error baseline: {mean_abs_error_baseline}")
    print()
# Out:
# RF_full_cortisol_react_loo_abs_error.csv
# ----------------------
# Corrected t-value: 0.681
# Corrected p-value: 0.250
# Mean difference (abs): 0.3068290110513483
# Mean abs error model: 3.7328842659021206
# Mean abs error baseline: 4.039713276953469
#
# RF_full_cort_20_min_loo_abs_error.csv
# ----------------------
# Corrected t-value: -0.224
# Corrected p-value: 0.412
# Mean difference (abs): -0.10820302456917047
# Mean abs error model: 5.0371701808728435
# Mean abs error baseline: 4.928967156303673
#
# RF_full_saa_react_loo_abs_error.csv
# ----------------------
# Corrected t-value: 1.039
# Corrected p-value: 0.152
# Mean difference (abs): 4.899602831255357
# Mean abs error model: 32.37395798507117
# Mean abs error baseline: 37.27356081632652
#
# RF_full_pana_delta_na_loo_abs_error.csv
# ----------------------
# Corrected t-value: -0.085
# Corrected p-value: 0.466
# Mean difference (abs): -0.0301601650566447
# Mean abs error model: 3.1648540426076646
# Mean abs error baseline: 3.1346938775510207
#
# RF_full_pana_delta_pa_loo_abs_error.csv
# ----------------------
# Corrected t-value: -0.503
# Corrected p-value: 0.309
# Mean difference (abs): -0.17863026196539578
# Mean abs error model: 4.111691486455191
# Mean abs error baseline: 3.9330612244897964

# %% [markdown]
# ### Support Vector Regressor

# %%
SVR_score_csvs = ["SVR_full_cortisol_react_loo_abs_error.csv", "SVR_full_cort_20_min_loo_abs_error.csv",
                 "SVR_full_saa_react_loo_abs_error.csv", "SVR_full_pana_delta_na_loo_abs_error.csv",
                 "SVR_full_pana_delta_pa_loo_abs_error.csv"]

for csv in SVR_score_csvs:
    df = pd.read_csv(csv)

    differences = df["baseline_abs_error"].values - df["model_abs_error"].values

    n = differences.shape[0]
    dfree = n - 1
    n_train = 24
    n_test  = 1    

    t_stat, p_val = mystats.compute_corrected_ttest(
        differences, dfree, n_train, n_test
    )
    mean_abs_error_model = np.mean(df["model_abs_error"].values)
    mean_abs_error_baseline = np.mean(df["baseline_abs_error"].values)

    print(csv)
    print("----------------------")
    print(f"Corrected t-value: {t_stat:.3f}")
    print(f"Corrected p-value: {p_val:.3f}")
    print(f"Mean difference (abs): {np.mean(differences)}")
    print(f"Mean abs error model: {mean_abs_error_model}")
    print(f"Mean abs error baseline: {mean_abs_error_baseline}")
    print()
# Out:
# SVR_full_cortisol_react_loo_abs_error.csv
# ----------------------
# Corrected t-value: 2.067
# Corrected p-value: 0.022
# Mean difference (abs): 0.9392644981298405
# Mean abs error model: 3.1004487788236297
# Mean abs error baseline: 4.039713276953469
#
# SVR_full_cort_20_min_loo_abs_error.csv
# ----------------------
# Corrected t-value: 0.485
# Corrected p-value: 0.315
# Mean difference (abs): 0.14948776343964718
# Mean abs error model: 4.779479392864026
# Mean abs error baseline: 4.928967156303673
#
# SVR_full_saa_react_loo_abs_error.csv
# ----------------------
# Corrected t-value: 0.768
# Corrected p-value: 0.223
# Mean difference (abs): 1.40728744660099
# Mean abs error model: 35.86627336972553
# Mean abs error baseline: 37.27356081632652
#
# SVR_full_pana_delta_na_loo_abs_error.csv
# ----------------------
# Corrected t-value: -0.571
# Corrected p-value: 0.285
# Mean difference (abs): -0.2385481483752853
# Mean abs error model: 3.373242025926306
# Mean abs error baseline: 3.1346938775510207
#
# SVR_full_pana_delta_pa_loo_abs_error.csv
# ----------------------
# Corrected t-value: -0.167
# Corrected p-value: 0.434
# Mean difference (abs): -0.028550691602820092
# Mean abs error model: 3.961611916092616
# Mean abs error baseline: 3.9330612244897964

# %% [markdown]
# ### XBoost Regressor

# %%
XGB_score_csvs = ["XGB_full_cortisol_react_loo_abs_error.csv", "XGB_full_cort_20_min_loo_abs_error.csv",
                 "XGB_full_saa_react_loo_abs_error.csv", "XGB_full_pana_delta_na_loo_abs_error.csv",
                 "XGB_full_pana_delta_pa_loo_abs_error.csv"]

for csv in XGB_score_csvs:
    df = pd.read_csv(csv)

    differences = df["baseline_abs_error"].values - df["model_abs_error"].values

    n = differences.shape[0]
    dfree = n - 1
    n_train = 24
    n_test  = 1    

    t_stat, p_val = mystats.compute_corrected_ttest(
        differences, dfree, n_train, n_test
    )
    mean_abs_error_model = np.mean(df["model_abs_error"].values)
    mean_abs_error_baseline = np.mean(df["baseline_abs_error"].values)

    print(csv)
    print("----------------------")
    print(f"Corrected t-value: {t_stat:.3f}")
    print(f"Corrected p-value: {p_val:.3f}")
    print(f"Mean difference (abs): {np.mean(differences)}")
    print(f"Mean abs error model: {mean_abs_error_model}")
    print(f"Mean abs error baseline: {mean_abs_error_baseline}")
    print()
# Out:
# XGB_full_cortisol_react_loo_abs_error.csv
# ----------------------
# Corrected t-value: 0.983
# Corrected p-value: 0.165
# Mean difference (abs): 0.6260707314749744
# Mean abs error model: 3.413642545478495
# Mean abs error baseline: 4.039713276953469
#
# XGB_full_cort_20_min_loo_abs_error.csv
# ----------------------
# Corrected t-value: -1.127
# Corrected p-value: 0.133
# Mean difference (abs): -0.7022964675874005
# Mean abs error model: 5.631263623891074
# Mean abs error baseline: 4.928967156303673
#
# XGB_full_saa_react_loo_abs_error.csv
# ----------------------
# Corrected t-value: 0.270
# Corrected p-value: 0.394
# Mean difference (abs): 1.725418351269156
# Mean abs error model: 35.548142465057374
# Mean abs error baseline: 37.27356081632652
#
# XGB_full_pana_delta_na_loo_abs_error.csv
# ----------------------
# Corrected t-value: 0.065
# Corrected p-value: 0.474
# Mean difference (abs): 0.033864079120815994
# Mean abs error model: 3.1008297984302042
# Mean abs error baseline: 3.1346938775510207
#
# XGB_full_pana_delta_pa_loo_abs_error.csv
# ----------------------
# Corrected t-value: -0.579
# Corrected p-value: 0.283
# Mean difference (abs): -0.21700992587269574
# Mean abs error model: 4.150071150362492
# Mean abs error baseline: 3.9330612244897964

# %% [markdown]
# # Mean abs error + std for cort + 20min for comparibility (ful data)

# %%
Cort_20_min_all = [
    "RF_full_cort_20_min_loo_abs_error.csv",
    "SVR_full_cort_20_min_loo_abs_error.csv",
    "XGB_full_cort_20_min_loo_abs_error.csv"]

for csv in Cort_20_min_all:
    df = pd.read_csv(csv)

    mean_abs_error_model = np.mean(df["model_abs_error"].values)
    mean_abs_error_baseline = np.mean(df["baseline_abs_error"].values)

    std_abs_error_model = df["model_abs_error"].std()
    std_abs_error_baseline = df["baseline_abs_error"].std()

    print(csv)
    print("----------------")
    print(f"Mean abs error model: {mean_abs_error_model}")
    print(f"+-std abs model: {std_abs_error_model}")
    print(f"Mean abs error baseline: {mean_abs_error_baseline}")
    print(f"+-std abs baseline: {std_abs_error_baseline}")
    print()
# Out:
# RF_full_cort_20_min_loo_abs_error.csv
# ----------------
# Mean abs error model: 5.0371701808728435
# +-std abs model: 4.295784313184869
# Mean abs error baseline: 4.928967156303673
# +-std abs baseline: 4.199432179172289
#
# SVR_full_cort_20_min_loo_abs_error.csv
# ----------------
# Mean abs error model: 4.779479392864026
# +-std abs model: 4.537582224053256
# Mean abs error baseline: 4.928967156303673
# +-std abs baseline: 4.199432179172289
#
# XGB_full_cort_20_min_loo_abs_error.csv
# ----------------
# Mean abs error model: 5.631263623891074
# +-std abs model: 4.668680009032043
# Mean abs error baseline: 4.928967156303673
# +-std abs baseline: 4.199432179172289
